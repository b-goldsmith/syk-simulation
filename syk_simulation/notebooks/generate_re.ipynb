# %% [markdown]
# # Generate Resource Estimates for Asymmetric Qubitization and QSP
#
# This notebook can be used to generate resource estimates and store them in the `re_data` directory as a CSV file.

# %%
import sys
import os

sys.path.insert(0, os.path.abspath("../.."))

# %%
# This cell is being used to generate Asymmetric Qubitization and QSP resource estimates and writing them to the re_data folder. 
import numpy as np
from syk_simulation.qubitization.re_utils import gather_aq_estimates, gather_aq_re_cpp
import os

time = 1 
J = 1
epsilon = 5e-5
random_seed=3
extra_qubits = 28

filename = "re_data/scale_N_J1_order1_control.csv"

Nlist = [68, 80, 96, 100] 

# Nlist = [100]

# Nlist = [8, 12, 16, 20, 24, 28, 32, 36, 48, 56, 64]

for N in Nlist:
    estimates = gather_aq_estimates(N=N, time=time, J=J, epsilon=epsilon, random_seed=3, extra_qubits=extra_qubits)
    # estimates = gather_aq_re_cpp(N=N, time=time, J=J, epsilon=epsilon, random_seed=3, extra_qubits=extra_qubits)

    rotation_eps = 1e-3
    total_t_gates = estimates['t_gates']+estimates['rotations']*(0.53* np.log2(1/rotation_eps) + 4.86)
    row = f"AQ,{N},{J},{time},{epsilon},{random_seed},{estimates['rotations']},{estimates['t_gates']},{total_t_gates},{estimates['qubit_highwater']}"

    with open(filename, "a", newline="") as f:
        f.write(f"{row}\n")
# Out:
# num_qubits: 136 - without extra: 108
# lambda=972.9189757288801 tau=972.9189757288801
# poly_degree=1020.4454034472291
# [PolyTaylorSeries] (Cheb) max 0.9500012177084668 is at 0.9800131238112044: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.5151104309701511e-06 in the domain [-1, 1] using degree 1020
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 4.761e+00
# iter: 002 --- err: 1.527e+00
# iter: 003 --- err: 1.979e-01
# iter: 004 --- err: 3.410e-03
# iter: 005 --- err: 9.832e-07
# iter: 006 --- err: 1.012e-13
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500014440181594 is at 0.10010018032066993: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.174586906296446e-06 in the domain [-1, 1] using degree 1020
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 4.394e+00
# iter: 002 --- err: 1.349e+00
# iter: 003 --- err: 1.650e-01
# iter: 004 --- err: 2.490e-03
# iter: 005 --- err: 5.549e-07
# iter: 006 --- err: 5.159e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 148 - without extra: 120
# lambda=1460.5934866804428 tau=1460.5934866804428
# poly_degree=1515.0127594835449
# [PolyTaylorSeries] (Cheb) max 0.9499980638030435 is at 0.06345158679636295: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.0076897922010972e-06 in the domain [-1, 1] using degree 1515
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 5.772e+00
# iter: 002 --- err: 1.860e+00
# iter: 003 --- err: 2.404e-01
# iter: 004 --- err: 4.159e-03
# iter: 005 --- err: 1.250e-06
# iter: 006 --- err: 1.619e-13
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.949998653984743 is at -0.32263522445778575: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.1899353310756805e-06 in the domain [-1, 1] using degree 1515
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 5.876e+00
# iter: 002 --- err: 1.908e+00
# iter: 003 --- err: 2.437e-01
# iter: 004 --- err: 4.243e-03
# iter: 005 --- err: 1.339e-06
# iter: 006 --- err: 1.813e-13
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 164 - without extra: 136
# lambda=2303.9999999999995 tau=2303.9999999999995
# poly_degree=2367.3486123006974
# [PolyTaylorSeries] (Cheb) max 0.9500015969816268 is at 0.10022007466226436: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.0163156807949104e-06 in the domain [-1, 1] using degree 2367
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 7.605e+00
# iter: 002 --- err: 2.565e+00
# iter: 003 --- err: 3.420e-01
# iter: 004 --- err: 6.866e-03
# iter: 005 --- err: 2.792e-06
# iter: 006 --- err: 6.034e-13
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500018386755464 is at 0.17180584437276758: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.1997008218717075e-06 in the domain [-1, 1] using degree 2367
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 7.609e+00
# iter: 002 --- err: 2.574e+00
# iter: 003 --- err: 3.496e-01
# iter: 004 --- err: 7.039e-03
# iter: 005 --- err: 2.871e-06
# iter: 006 --- err: 6.262e-13
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 168 - without extra: 140
# lambda=2551.551815399144 tau=2551.551815399144
# poly_degree=2617.0925158122436
# [PolyTaylorSeries] (Cheb) max 0.9500001609655163 is at -0.4549460813481266: normalizing
# [PolyTaylorSeries] (Cheb) average error = 7.833848865965512e-07 in the domain [-1, 1] using degree 2617
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 7.912e+00
# iter: 002 --- err: 2.675e+00
# iter: 003 --- err: 3.618e-01
# iter: 004 --- err: 7.283e-03
# iter: 005 --- err: 2.997e-06
# iter: 006 --- err: 6.698e-13
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500007414017757 is at 0.9973107467794797: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.133632927020154e-06 in the domain [-1, 1] using degree 2617
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 8.265e+00
# iter: 002 --- err: 2.898e+00
# iter: 003 --- err: 4.080e-01
# iter: 004 --- err: 9.088e-03
# iter: 005 --- err: 4.383e-06
# iter: 006 --- err: 1.301e-12
# iter: 007 --- err: 1.082e-13
# [sym_qsp] Stop criteria satisfied.

# %%
print(filename)

# %%
with open(filename, "a", newline="") as f:
    f.write(f"{row}\n")

# %%
# This cell is being used to generate Asymmetric Qubitization resource estimates and writing them to the re_data folder. 
import numpy as np
from syk_simulation.qubitization.re_utils import gather_aq_estimates, gather_aq_re_cpp
import csv
import os

time = 1 
J = 1
epsilon = 1e-3
random_seed=3
extra_qubits = 25

filename = "re_data/scale_eps_J1_order1_control.csv"

N = 100
# cos_filename = f"re_data/cos_angles_N{N}.npy"
# sin_filename = f"re_data/sin_angles_N{N}.npy"
# if os.path.exists(cos_filename):
#     cos_angles = np.load(cos_filename)
#     sin_angles =  np.load(sin_filename)
#     phases = (cos_angles, sin_angles)
# else:
#     phases = None

Epsilonlist = [5e-4, 5e-5, 5e-6, 5e-7, 5e-8, 5e-9, 5e-10, 5e-11, 5e-12, 5e-13]
for epsilon in Epsilonlist:
    estimates = gather_aq_estimates(N=N, time=time, J=J, epsilon=epsilon, random_seed=3, extra_qubits=extra_qubits)
    # estimates = gather_aq_re_cpp(N=N, time=time, J=J, epsilon=epsilon, random_seed=3, extra_qubits=extra_qubits)

    rotation_eps = epsilon
    total_t_gates = estimates['t_gates']+estimates['rotations']*(0.53* np.log2(1/rotation_eps) + 4.86)
    row = f"AQ,{N},{J},{time},{epsilon},{random_seed},{estimates['rotations']},{estimates['t_gates']},{total_t_gates},{estimates['qubit_highwater']}"

    with open(filename, "a", newline="") as f:
        f.write(f"{row}\n")
# Out:
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=169.0595868589929
# [PolyTaylorSeries] (Cheb) max 0.9500061245844923 is at 0.05313882014708108: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.1138996552612635e-05 in the domain [-1, 1] using degree 169
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.679e-02
# iter: 004 --- err: 4.308e-04
# iter: 005 --- err: 5.434e-08
# iter: 006 --- err: 7.217e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9499848608661298 is at 0.08502212787552495: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.968649360102957e-05 in the domain [-1, 1] using degree 169
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.755e-01
# iter: 003 --- err: 6.217e-02
# iter: 004 --- err: 9.849e-04
# iter: 005 --- err: 2.079e-07
# iter: 006 --- err: 1.151e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=173.16089876955266
# [PolyTaylorSeries] (Cheb) max 0.9500001590776734 is at 0.05313866495378993: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.0303838772324908e-06 in the domain [-1, 1] using degree 173
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.428e-08
# iter: 006 --- err: 5.344e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500002370145855 is at 0.9990063004065877: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.8813951287445161e-06 in the domain [-1, 1] using degree 173
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.152e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=176.9531922232066
# [PolyTaylorSeries] (Cheb) max 0.9499999858065431 is at 0.05313865282983704: normalizing
# [PolyTaylorSeries] (Cheb) average error = 2.8904829073778116e-07 in the domain [-1, 1] using degree 176
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 6.530e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9499999893974482 is at 0.999006642787288: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.534157150860291e-07 in the domain [-1, 1] using degree 176
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.147e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=180.51279115155438
# [PolyTaylorSeries] (Cheb) max 0.9499999902806766 is at 0.05313864829550235: normalizing
# [PolyTaylorSeries] (Cheb) average error = 2.2666830302789376e-08 in the domain [-1, 1] using degree 180
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 5.429e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9499999969635705 is at 0.9990066736362185: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.0935361595444671e-08 in the domain [-1, 1] using degree 180
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.063e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=183.8880918169006
# [PolyTaylorSeries] (Cheb) max 0.9499999988628509 is at 0.05313864795580117: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.4721959965685594e-09 in the domain [-1, 1] using degree 183
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 8.131e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500000000152122 is at 0.042510918120368814: normalizing
# [PolyTaylorSeries] (Cheb) average error = 2.7209189040755534e-09 in the domain [-1, 1] using degree 183
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.141e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=187.11221419751368
# [PolyTaylorSeries] (Cheb) max 0.9499999999115778 is at 0.05313864793964235: normalizing
# [PolyTaylorSeries] (Cheb) average error = 8.111362630180974e-11 in the domain [-1, 1] using degree 187
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 6.153e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.949999999950023 is at 0.042510918068189: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.670655492419515e-10 in the domain [-1, 1] using degree 187
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.123e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=190.2090815338424
# [PolyTaylorSeries] (Cheb) max 0.9499999999778787 is at 0.053138647937670494: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.7668387378155793e-11 in the domain [-1, 1] using degree 190
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 6.784e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9499999999952282 is at 0.04251091807483364: normalizing
# [PolyTaylorSeries] (Cheb) average error = 7.872702177669222e-12 in the domain [-1, 1] using degree 190
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.243e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=193.19668563994844
# [PolyTaylorSeries] (Cheb) max 0.9499999999990744 is at 0.05313864793958768: normalizing
# [PolyTaylorSeries] (Cheb) average error = 8.609682411453435e-13 in the domain [-1, 1] using degree 193
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 8.924e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9499999999987664 is at 0.9990066760735278: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.7611312061460716e-12 in the domain [-1, 1] using degree 193
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.098e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=196.0889884072352
# [PolyTaylorSeries] (Cheb) max 0.9500000000000284 is at 0.053138647941663654: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.5568574207591723e-13 in the domain [-1, 1] using degree 196
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 6.098e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500000000001354 is at 0.04251091807172887: normalizing
# [PolyTaylorSeries] (Cheb) average error = 7.261486550946828e-14 in the domain [-1, 1] using degree 196
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.170e-14
# [sym_qsp] Stop criteria satisfied.
# num_qubits: 87 - without extra: 62
# lambda=147.8016689125442 tau=147.8016689125442
# poly_degree=198.89709960807818
# [PolyTaylorSeries] (Cheb) max 0.9500000000002411 is at 0.05313864793827051: normalizing
# [PolyTaylorSeries] (Cheb) average error = 3.347246091411904e-14 in the domain [-1, 1] using degree 198
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.407e+00
# iter: 002 --- err: 3.481e-01
# iter: 003 --- err: 3.678e-02
# iter: 004 --- err: 4.306e-04
# iter: 005 --- err: 5.427e-08
# iter: 006 --- err: 5.316e-15
# [sym_qsp] Stop criteria satisfied.
# [PolyTaylorSeries] (Cheb) max 0.9500000000002041 is at 0.04251091806189171: normalizing
# [PolyTaylorSeries] (Cheb) average error = 1.6756249165972292e-14 in the domain [-1, 1] using degree 198
# [sym_qsp] Iterative optimization to err 1.000e-12 or max_iter 100.
# iter: 001 --- err: 1.642e+00
# iter: 002 --- err: 4.756e-01
# iter: 003 --- err: 6.219e-02
# iter: 004 --- err: 9.861e-04
# iter: 005 --- err: 2.084e-07
# iter: 006 --- err: 1.281e-14
# [sym_qsp] Stop criteria satisfied.
